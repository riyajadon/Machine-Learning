# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir(r"C:\Users\LENOVO\Documents\Data Science\DataSets")

# %%
df=pd.read_csv("VC_Startups.csv")

# %%
df.head(6)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12

# %%
x=df.iloc[:,0].values
y=df.iloc[:,4].values

# %%
plt.scatter(x,y,label='',color='c')
plt.xlabel('R&D')
plt.ylabel('Profit')
plt.title('Profit and R&D Spend')
# Out:
# Text(0.5, 1.0, 'Profit and R&D Spend')

# %%
x=df.iloc[:,1].values
y=df.iloc[:,4].values

# %%
plt.scatter(x,y,label='',color='c')
plt.xlabel('Administration')
plt.ylabel('Profit')
plt.title('Profit and Administration')
# Out:
# Text(0.5, 1.0, 'Profit and Administration')

# %%
x=df.iloc[:,2].values
y=df.iloc[:,4].values

# %%
plt.scatter(x,y,label='',color='c')
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.title('Profit and Marketing Spend')
# Out:
# Text(0.5, 1.0, 'Profit and Marketing Spend')

# %%
x=np.linspace(0,10,100)
y=np.sqrt(x)
plt.plot(x,y,label='',color='b')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Anything')
plt.show()

# %%
#sub plot(no. of rows, no. of column, plot no. you r refering to)
plt.subplot(1,2,1)
plt.plot(x,y,'g')
plt.subplot(1,2,2)
plt.plot(x,y,'o')
plt.show()

# %%
#object oriented approch of plotting a graph
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('X vs Y')
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.4,0.55,0.4,0.3])
axes1.plot([0.1,0.50,0.13,0.16],[10,15,18,25],'red')
axes.set_title('X vs Y')
axes2.plot(x,y,'green')

# %%
fig=plt.figure(figsize=(1,1),dpi=200)
#Create a figure
#figsize: tuples of integer, optional,default:none
#width=, height in inches,if not provided default to rc
#figure.figsize
#dpi(Dots pe inch):tuples of integer, optional, default: None
#resolution of the figure. if not provided, default rc to figure
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, axes= plt.subplots(nrows=2,nclos=3,figsize=(8,2),dpi=300)
axes[0].plot(x,y,'b')
axes[1].plt(y,x,'g')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51f0c5098a24> in <module>
# ----> 1 fig, axes= plt.subplots(nrows=2,nclos=3,figsize=(8,2),dpi=300)
#       2 axes[0].plot(x,y,'b')
#       3 axes[1].plt(y,x,'g')
#       4 plt.tight_layout()
#
# NameError: name 'plt' is not defined

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cube')
ax.legend(loc=0)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,y)
ax.plot(x,y,color='#FF8c10',linewidth=20)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(x,y,color='blue',linewidth=20,linestyle=':',alpha=0-100,marker='o', markersize=10) #alpha = transparency

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(x,y,color='blue',linewidth=20,linestyle=':',alpha=0-100,marker='o', markersize=10,markerfacecolor='red',markeredgewidth=10,markeredgecolor='yellow')
ax.set_xlim([0,1])
ax.set_ylim([0,1])
# Out:
# (0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
days=[1,2,3,4,5,6]
max_temp=[50,20,51,52,48,49]
min_temp=[45,48,44,45,46,47]
avg_temp=[45,48,49,21,48,47]
plt.xlabel('Days')
plt.ylabel('Temprature')
plt.title('Days vs Temprature')
plt.plot(days,max_temp,label='max')
plt.plot(days,min_temp,label='min')
plt.plot(days,avg_temp,label='avg')
plt.legend(loc='best',shadow=True,fontsize='large')
plt.grid()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
temp=[30,32,33,28.5,35,29,29]
ice_creams_count=[100,115,115,75,125,79,89]
plt.scatter(temp,ice_creams_count)
plt.xlabel('Temprature')
plt.ylabel('Solid ice cream')
plt.title('Temprature vs Solid ice cream')
plt.show()

# %%
numbers=[0.1,0.5,1,1.5,2,4,5.5,6,8,9]
plt.hist(numbers,bins=3)
plt.xlabel("Numbers")
plt.ylabel('Frequency')
plt.show()

# %%
values=[1,2,5,6,6,7,7,8,8,8,9,10,21]
plt.boxplot(values)
plt.yticks(range(1,22))
plt.ylabel('Values')
plt.grid()
plt.show()

# %%
labels=['python','java','javascript','c#']
usage=[69.8,45.3,38.8,34.4]
y_positions=range(len(labels))
plt.bar(y_positions,usage)
plt.xticks(y_positions)
plt.ylabel('usage%')
plt.title('Programming language usage')
plt.grid()
plt.show()

# %%
sizes=[25,20,45,20]
labels=['cats','dog','tiger','gotas']
plt.pie(sizes,labels=labels,autopct='%.2f',explode=[0,0,0,0.07])
plt.axis('Equal')
plt.show()

# %%
import os
os.chdir("C:\\Users\Tariq Mehmood\Desktop\Python program")

# %%
df=pd.read_csv("VC_Startups.csv")

# %%
X=df.iloc[:,:-1].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
X=df.iloc[:,0].values

# %%
Y=df.iloc[:,4].values
Y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
plt.scatter(X,Y,label='',color='k')
plt.xlabel('R&D')
plt.ylabel('Profit')
plt.title('Profit and R&D')
plt.show()

# %%
X=df.iloc[:,1].values

# %%
plt.scatter(X,Y,label='',color='k')
plt.xlabel('Administrator')
plt.ylabel('Profit')
plt.title('Profit and administrator')
plt.show()

# %%
X=df.iloc[:,2].values

# %%
plt.scatter(X,Y,label='',color='k')
plt.xlabel('Markiting')
plt.ylabel('Profit')
plt.title('Profit and Markiting Spend')
plt.show()

# %%
from numpy import array
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()
X=df.iloc[:,:-1].values

# %%
X[:,3]=labelencoder.fit_transform(X[:,3])
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        [144372.41, 118671.85, 383199.62, 2],
#        [142107.34, 91391.77, 366168.42, 1],
#        [131876.9, 99814.71, 362861.36, 2],
#        [134615.46, 147198.87, 127716.82, 0],
#        [130298.13, 145530.06, 323876.68, 1],
#        [120542.52, 148718.95, 311613.29, 2],
#        [123334.88, 108679.17, 304981.62, 0],
#        [101913.08, 110594.11, 229160.95, 1],
#        [100671.96, 91790.61, 249744.55, 0],
#        [93863.75, 127320.38, 249839.44, 1],
#        [91992.39, 135495.07, 252664.93, 0],
#        [119943.24, 156547.42, 256512.92, 1],
#        [114523.61, 122616.84, 261776.23, 2],
#        [78013.11, 121597.55, 264346.06, 0],
#        [94657.16, 145077.58, 282574.31, 2],
#        [91749.16, 114175.79, 294919.57, 1],
#        [86419.7, 153514.11, 0.0, 2],
#        [76253.86, 113867.3, 298664.47, 0],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
# array([[55493.95, 103057.49, 214634.81, 1],
#        [46014.02, 85047.44, 205517.64, 2],
#        [75328.87, 144135.98, 134050.07, 1],
#        [46426.07, 157693.92, 210797.67, 0],
#        [91749.16, 114175.79, 294919.57, 1],
#        [130298.13, 145530.06, 323876.68, 1],
#        [119943.24, 156547.42, 256512.92, 1],
#        [1000.23, 124153.04, 1903.93, 2],
#        [542.05, 51743.15, 0.0, 2],
#        [65605.48, 153032.06, 107138.38, 2],
#        [114523.61, 122616.84, 261776.23, 2],
#        [61994.48, 115641.28, 91131.24, 1],
#        [63408.86, 129219.61, 46085.25, 0],
#        [78013.11, 121597.55, 264346.06, 0],
#        [23640.93, 96189.63, 148001.11, 0],
#        [76253.86, 113867.3, 298664.47, 0],
#        [15505.73, 127382.3, 35534.17, 2],
#        [120542.52, 148718.95, 311613.29, 2],
#        [91992.39, 135495.07, 252664.93, 0],
#        [64664.71, 139553.16, 137962.62, 0],
#        [131876.9, 99814.71, 362861.36, 2],
#        [94657.16, 145077.58, 282574.31, 2],
# ...

# %%
Y_train
# Out:
# array([ 96778.92,  96479.51, 105733.54,  96712.8 , 124266.9 , 155752.6 ,
#        132602.65,  64926.08,  35673.41, 101004.64, 129917.04,  99937.59,
#         97427.84, 126992.93,  71498.49, 118474.03,  69758.98, 152211.77,
#        134307.35, 107404.34, 156991.12, 125370.37,  78239.91,  14681.4 ,
#        191792.06, 141585.52,  89949.14, 108552.04, 156122.51, 108733.99,
#         90708.19, 111313.02, 122776.86, 149759.96,  81005.76,  49490.75,
#        182901.99, 192261.83,  42559.73,  65200.33])

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regressor.coef_
# Out:
# array([7.77203690e-01, 3.02432445e-02, 3.49236072e-02, 3.15877202e+02])

# %%
regressor.intercept_
# Out:
# 42658.087123248944

# %%
regressor.score(X_train,Y_train)
# Out:
# 0.9500009880362248

# %%
Y_pred=regressor.predict(X_test)
Y_pred
# Out:
# array([103959.40508021, 132398.73236694, 133529.03790148,  72958.28368314,
#        179534.78737166, 115533.62584099,  67476.95847883,  98504.36199396,
#        114789.16083781, 168972.21909945])
